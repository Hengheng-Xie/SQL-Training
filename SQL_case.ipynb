# %%
import csv, sqlite3
import pandas as pd

con = sqlite3.connect("sqlite_db_pythonsqlite.db")
cur = con.cursor()

# %%
res = cur.execute('SELECT * FROM FACILITIES')
df = pd.DataFrame(res.fetchall())
df.columns = [description[0] for description in res.description]
df
# Out:
#    facid             name  membercost  guestcost  initialoutlay  \
# 0      0   Tennis Court 1         5.0       25.0          10000
# 1      1   Tennis Court 2         5.0       25.0           8000
# 2      2  Badminton Court         0.0       15.5           4000
# 3      3     Table Tennis         0.0        5.0            320
# 4      4   Massage Room 1         9.9       80.0           4000
# 5      5   Massage Room 2         9.9       80.0           4000
# 6      6     Squash Court         3.5       17.5           5000
# 7      7    Snooker Table         0.0        5.0            450
# 8      8       Pool Table         0.0        5.0            400
#
#    monthlymaintenance
# 0                 200
# 1                 200
# 2                  50
# 3                  10
# 4                3000
# 5                3000
# 6                  80
# 7                  15
# 8                  15

# %%
# %pip install jupysql --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql sqlite:///sqlite_db_pythonsqlite.db
# Out:
# Connecting to 'sqlite:///sqlite_db_pythonsqlite.db'

# %%
# %sql SELECT * FROM FACILITIES
# Out:
# Running query in 'sqlite:///sqlite_db_pythonsqlite.db'
# +-------+-----------------+------------+-----------+---------------+--------------------+
# | facid |       name      | membercost | guestcost | initialoutlay | monthlymaintenance |
# +-------+-----------------+------------+-----------+---------------+--------------------+
# |   0   |  Tennis Court 1 |     5      |     25    |     10000     |        200         |
# |   1   |  Tennis Court 2 |     5      |     25    |      8000     |        200         |
# |   2   | Badminton Court |     0      |    15.5   |      4000     |         50         |
# |   3   |   Table Tennis  |     0      |     5     |      320      |         10         |
# |   4   |  Massage Room 1 |    9.9     |     80    |      4000     |        3000        |
# |   5   |  Massage Room 2 |    9.9     |     80    |      4000     |        3000        |
# |   6   |   Squash Court  |    3.5     |    17.5   |      5000     |         80         |
# ...

# %%
# %sql SELECT * FROM Bookings WHERE starttime LIKE '2012%'
# Out:
# Running query in 'sqlite:///sqlite_db_pythonsqlite.db'
# +--------+-------+-------+---------------------+-------+
# | bookid | facid | memid |      starttime      | slots |
# +--------+-------+-------+---------------------+-------+
# |   0    |   3   |   1   | 2012-07-03 11:00:00 |   2   |
# |   1    |   4   |   1   | 2012-07-03 08:00:00 |   2   |
# |   2    |   6   |   0   | 2012-07-03 18:00:00 |   2   |
# |   3    |   7   |   1   | 2012-07-03 19:00:00 |   2   |
# |   4    |   8   |   1   | 2012-07-03 10:00:00 |   1   |
# |   5    |   8   |   1   | 2012-07-03 15:00:00 |   1   |
# |   6    |   0   |   2   | 2012-07-04 09:00:00 |   3   |
# |   7    |   0   |   2   | 2012-07-04 15:00:00 |   3   |
# |   8    |   4   |   3   | 2012-07-04 13:30:00 |   2   |
# |   9    |   4   |   0   | 2012-07-04 15:00:00 |   2   |
# +--------+-------+-------+---------------------+-------+
# Truncated to displaylimit of 10.

# %%
# %sql SELECT * FROM Members
# Out:
# Running query in 'sqlite:///sqlite_db_pythonsqlite.db'
# +-------+----------+-----------+------------------------------------+---------+----------------+---------------+---------------------+
# | memid | surname  | firstname |              address               | zipcode |   telephone    | recommendedby |       joindate      |
# +-------+----------+-----------+------------------------------------+---------+----------------+---------------+---------------------+
# |   0   |  GUEST   |   GUEST   |               GUEST                |    0    | (000) 000-0000 |               | 2012-07-01 00:00:00 |
# |   1   |  Smith   |   Darren  |     8 Bloomsbury Close, Boston     |   4321  |  555-555-5555  |               | 2012-07-02 12:02:05 |
# |   2   |  Smith   |   Tracy   |    8 Bloomsbury Close, New York    |   4321  |  555-555-5555  |               | 2012-07-02 12:08:23 |
# ...

# %%
# %sql SELECT DISTINCT (full_name), name AS facility FROM Bookings AS b LEFT JOIN Facilities AS f ON b.facid = f.facid LEFT JOIN (SELECT surname || ' ' || firstname as full_name, memid FROM Members )AS m ON b.memid = m.memid WHERE b.memid != 0
# Out:
# Running query in 'sqlite:///sqlite_db_pythonsqlite.db'
# +--------------+----------------+
# |  full_name   |    facility    |
# +--------------+----------------+
# | Smith Darren |  Table Tennis  |
# | Smith Darren | Massage Room 1 |
# | Smith Darren | Snooker Table  |
# | Smith Darren |   Pool Table   |
# | Smith Tracy  | Tennis Court 1 |
# |  Rownam Tim  | Massage Room 1 |
# | Smith Darren |  Squash Court  |
# | Smith Tracy  | Snooker Table  |
# | Smith Tracy  |   Pool Table   |
# |  Rownam Tim  |   Pool Table   |
# +--------------+----------------+
# Truncated to displaylimit of 10.

# %%
# %sql SELECT strftime('%m', starttime) AS month, memid FROM Bookings
# Out:
# Running query in 'sqlite:///sqlite_db_pythonsqlite.db'
# +-------+-------+
# | month | memid |
# +-------+-------+
# |   07  |   1   |
# |   07  |   1   |
# |   07  |   0   |
# |   07  |   1   |
# |   07  |   1   |
# |   07  |   1   |
# |   07  |   2   |
# |   07  |   2   |
# |   07  |   3   |
# |   07  |   0   |
# +-------+-------+
# Truncated to displaylimit of 10.
